# %% [markdown]
# ## **MACHINE LEARNING IN ARCHAEOLOGY:​ BASICS**
# ###**EXERCISE 2**: Deep Learning Potsherd Detection On Drone Imagery​
#
# **Iban Berganzo-Besga** 1,2
# (https://orcid.org/0000-0002-6161-2452)
#
# 1. **Post-doctoral Fellow**
#
# * *Ramsey Laboratory for Environmental Archaeology (RLEA)​
# University of Toronto Mississauga (UTM)*​
#
# * https://www.utm.utoronto.ca/ramsey-lab/people/iban-berganzo-besga
#
# 2. **Associate Researcher​**
#
# * *Landscape Archaeology Research Group (GIAP)​
# Catalan Institute of Classical Archaeology (ICAC)​*
#
# * https://icac.cat/en/who-are-we/staff/iberganzo/
#
# ---

# %% [markdown]
# ### 1. Sources & Algorithms Selection
#
# **Sources**: Drone Imagery
#
# **Algorithm**: Instance Segmentation (YOLOv9)

# %%
# !git clone https://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@github.com/iberganzo/MLArchaeologyBasics.git
# Out:
# Cloning into 'MLArchaeologyBasics'...
# remote: Enumerating objects: 477, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 477 (delta 58), reused 11 (delta 11), pack-reused 358
# Receiving objects: 100% (477/477), 25.30 MiB | 13.26 MiB/s, done.
# Resolving deltas: 100% (114/114), done.

# %% [markdown]
# ### 2. Data Pretreatment
#
# **Image Format & Size**: JPG, 1024x1024 px
#
# **Image Labelling**: YOLO format
#
# **Work Dataset**: Training (60%), validation (20%) and testing (20%)

# %% [markdown]
# Remove previous data

# %%
# !rm MLArchaeologyBasics/yolov9/dataset/images/train/*
# !rm MLArchaeologyBasics/yolov9/dataset/images/val/*
# !rm MLArchaeologyBasics/yolov9/dataset/images/test/*
# !rm MLArchaeologyBasics/yolov9/dataset/labels/train/*
# !rm MLArchaeologyBasics/yolov9/dataset/labels/val/*
# !rm MLArchaeologyBasics/yolov9/dataset/labels/test/*

# !rm MLArchaeologyBasics/yolov9/dataset/train.txt
# !rm MLArchaeologyBasics/yolov9/dataset/train.cache
# !rm MLArchaeologyBasics/yolov9/dataset/val.txt
# !rm MLArchaeologyBasics/yolov9/dataset/val.cache
# !rm MLArchaeologyBasics/yolov9/dataset/test.txt
# !rm MLArchaeologyBasics/yolov9/dataset/test.cache

# !rm MLArchaeologyBasics/yolov9/labelling/yolo/*
# !rm MLArchaeologyBasics/yolov9/labelling/via/*

# %% [markdown]
# Add your images to the MLArchaeologyBasics/yolov9/dataset/images/ folders
#
# Create the TXT files associated with the train, val and test images in the MLArchaeologyBasics/yolov9/dataset/ folder

# %%
# !cp MLArchaeologyBasics/exercise2/train/* MLArchaeologyBasics/yolov9/dataset/images/train/
# !cp MLArchaeologyBasics/exercise2/val/* MLArchaeologyBasics/yolov9/dataset/images/val/
# !cp MLArchaeologyBasics/exercise2/test/* MLArchaeologyBasics/yolov9/dataset/images/test/

# %% [markdown]
# Add your labelled VIA JSON data to the MLArchaeologyBasics/yolov9/labelling/via/ folder

# %%
# %cd MLArchaeologyBasics/yolov9/labelling/
# !python3 viatoyolo.py --img 1024 1024
# %cd ../../../
# Out:
# /content/MLArchaeologyBasics/yolov9/labelling
# Processed image:  1012
# Processed image:  1016
# Processed image:  1048
# Processed image:  1087
# Processed image:  1165
# Processed image:  190
# Processed image:  978
# Processed image:  979
# Processed image:  1009
# Processed image:  1011
# Processed image:  1013
# Processed image:  1047
# Processed image:  1050
# Processed image:  1051
# Processed image:  1083
# Processed image:  1084
# Processed image:  1117
# Processed image:  1120
# Processed image:  1151
# Processed image:  1169
# Processed image:  1174
# Processed image:  1310
# Processed image:  1118
# Processed image:  86
# Processed image:  1015
# Processed image:  1044
# Processed image:  1052
# Processed image:  1116
# Processed image:  1152
# Processed image:  1187
# /content

# %% [markdown]
# Download and add the resulting labelled YOLO TXT data to the MLArchaeologyBasics/yolov9/dataset/labels/ folders

# %%
# !apt-get update
# !apt-get install megatools
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [929 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,922 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,556 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,189 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,393 kB]
# Fetched 9,252 kB in 3s (2,710 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   megatools
# 0 upgraded, 1 newly installed, 0 to remove and 46 not upgraded.
# Need to get 207 kB of archives.
# After this operation, 898 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 megatools amd64 1.10.3-1build1 [207 kB]
# Fetched 207 kB in 2s (132 kB/s)
# Selecting previously unselected package megatools.
# (Reading database ... 121925 files and directories currently installed.)
# Preparing to unpack .../megatools_1.10.3-1build1_amd64.deb ...
# Unpacking megatools (1.10.3-1build1) ...
# Setting up megatools (1.10.3-1build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !mkdir MLArchaeologyBasics/yolov9/runs/train-seg/exercise2_yolov9_seg_train_iban/weights/
# %cd MLArchaeologyBasics/yolov9/
# !megadl 'https://mega.nz/#!VJ9AASoQ!p2S9oeIKUGKncYXO4wQ682riWQYUIxjhToQiB77_uc8'
# %cd runs/train-seg/exercise2_yolov9_seg_train_iban/weights/
# !megadl 'https://mega.nz/#!RNFBCJCR!l3N3p-1vgizHno6OnjU-Y8lArliDu4YISkZid7kaawE'
# %cd ../../../../
# Out:
# /content/MLArchaeologyBasics/yolov9
# Downloaded gelan-c-seg.pt
# /content/MLArchaeologyBasics/yolov9/runs/train-seg/exercise2_yolov9_seg_train_iban/weights
# Downloaded best.pt
# /content/MLArchaeologyBasics/yolov9

# %% [markdown]
# ### 3. Algorithm Training
#
# **Hyperparameters**: Image Size (1024x1024px), Epochs (50), Batch Size (4)
#
# **Training Data**: Transfer Learning

# %%
# !python3 segment/train.py --workers 8 --device 0 --batch 4  --data data/train.yaml --img 1024 --cfg models/segment/gelan-c-seg_custom.yaml --weights 'gelan-c-seg.pt' --hyp hyp.scratch-high.yaml --no-overlap --epochs 50 --close-mosaic 10 --name exercise2_yolov9_seg_train
# Out:
# 2024-06-25 09:59:59.040166: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-25 09:59:59.040220: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-25 09:59:59.041675: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-25 09:59:59.049146: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-25 10:00:00.264497: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# segment/train: weights=gelan-c-seg.pt, cfg=models/segment/gelan-c-seg_custom.yaml, data=data/train.yaml, hyp=hyp.scratch-high.yaml, epochs=50, batch_size=4, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train-seg, name=exercise2_yolov9_seg_train, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, close_mosaic=10, mask_ratio=4, no_overlap=True
# YOLO 🚀 2024-6-25 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, obj=0.7, obj_pw=1.0, dfl=1.5, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# TensorBoard: Start with 'tensorboard --logdir runs/train-seg', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   7627379  models.yolo.Segment                     [1, 32, 256, [256, 512, 512]]
# gelan-c-seg_custom summary: 657 layers, 27573811 parameters, 27573795 gradients
#
# Transferred 991/997 items from gelan-c-seg.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 163 weight(decay=0.0), 173 weight(decay=0.0005), 172 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/MLArchaeologyBasics/yolov9/dataset/train.cache... 18 images, 0 backgrounds, 0 corrupt: 100% 18/18 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/MLArchaeologyBasics/yolov9/dataset/val... 6 images, 0 backgrounds, 0 corrupt: 100% 6/6 [00:00<00:00, 233.06it/s]
# val: New cache created: /content/MLArchaeologyBasics/yolov9/dataset/val.cache
# Plotting labels to runs/train-seg/exercise2_yolov9_seg_train/labels.jpg...
# Image sizes 1024 train, 1024 val
# Using 2 dataloader workers
# Logging results to runs/train-seg/exercise2_yolov9_seg_train
# Starting training for 50 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        0/49      7.96G      1.735     0.9547       4.73      1.206         21       1024: 100% 5/5 [00:13<00:00,  2.60s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.21it/s]
#                    all          6         63    0.00889      0.254     0.0065    0.00338     0.0106      0.302    0.00769    0.00296
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/49      8.78G      1.606      1.122      4.191       1.22         32       1024: 100% 5/5 [00:04<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.63it/s]
#                    all          6         63      0.414      0.111      0.136     0.0632      0.032      0.429      0.102     0.0396
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/49      8.78G      1.676      1.041      3.969      1.376         11       1024: 100% 5/5 [00:09<00:00,  1.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.70it/s]
#                    all          6         63      0.462      0.111      0.135     0.0608     0.0239      0.683     0.0997     0.0379
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/49      8.78G      1.428     0.9031      3.715       1.24         33       1024: 100% 5/5 [00:04<00:00,  1.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.33it/s]
#                    all          6         63      0.675       0.54      0.639      0.324       0.69      0.603      0.625      0.295
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/49      8.78G      1.698     0.9294      2.791        1.2          7       1024: 100% 5/5 [00:04<00:00,  1.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.78it/s]
#                    all          6         63       0.86      0.684      0.775      0.427      0.817      0.698      0.768      0.394
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/49      9.33G      1.425     0.6782      1.867       1.07         72       1024: 100% 5/5 [00:05<00:00,  1.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.39it/s]
#                    
0.469
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       41/49      9.33G      1.411     0.7039     0.9738      1.185          9       1024: 100% 5/5 [00:03<00:00,  1.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.72it/s]
#                    all          6         63      0.895       0.73      0.873      0.526      0.914      0.746       0.87      0.469
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       42/49      9.33G      1.754     0.9448      1.398      1.046         19       1024: 100% 5/5 [00:03<00:00,  1.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.35it/s]
#                    all          6         63      0.884      0.725      0.854      0.508      0.903      0.741      0.832      0.445
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       43/49      9.33G      1.533     0.6475       1.29      1.153          5       1024: 100% 5/5 [00:03<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.34it/s]
#                    all          6         63      0.884      0.725      0.854      0.508      0.903      0.741      0.832      0.445
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       44/49      9.33G      1.246     0.6744      1.095      1.062         19       1024: 100% 5/5 [00:04<00:00,  1.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.76it/s]
#                    all          6         63      0.884      0.725      0.854      0.508      0.903      0.741      0.832      0.445
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       45/49      9.33G      1.343     0.9684       1.25      1.021          3       1024: 100% 5/5 [00:03<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.39it/s]
#                    all          6         63      0.861      0.746      0.875      0.505       0.88      0.746      0.835      0.441
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       46/49      9.33G      1.363     0.5863      1.184      1.153          9       1024: 100% 5/5 [00:03<00:00,  1.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.09it/s]
#                    all          6         63      0.861      0.746      0.875      0.505       0.88      0.746      0.835      0.441
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       47/49      9.33G      1.339     0.6318      1.106      1.092          5       1024: 100% 5/5 [00:03<00:00,  1.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.79it/s]
#                    all          6         63      0.861      0.746      0.875      0.505       0.88      0.746      0.835      0.441
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       48/49      9.33G      1.338     0.4928     0.9959      1.215         10       1024: 100% 5/5 [00:03<00:00,  1.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.35it/s]
#                    all          6         63      0.861      0.746      0.875      0.505       0.88      0.746      0.835      0.441
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       49/49      9.33G      1.512     0.6795       1.17      1.215         13       1024: 100% 5/5 [00:03<00:00,  1.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.32it/s]
#                    all          6         63      0.873      0.746      0.866      0.514      0.893      0.762      0.863      0.456
#
# 50 epochs completed in 0.102 hours.
# Optimizer stripped from runs/train-seg/exercise2_yolov9_seg_train/weights/last.pt, 55.8MB
# Optimizer stripped from runs/train-seg/exercise2_yolov9_seg_train/weights/best.pt, 55.8MB
#
# Validating runs/train-seg/exercise2_yolov9_seg_train/weights/best.pt...
# Fusing layers...
# gelan-c-seg_custom summary: 414 layers, 27362899 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.57it/s]
#                    all          6         63      0.897       0.73      0.873      0.525      0.917      0.746       0.87      0.469
# Results saved to runs/train-seg/exercise2_yolov9_seg_train

# %% [markdown]
# ### 3. Algorithm Evaluation: Validation Dataset
#
# **Recall**: TP / (TP + FN)
#
# **Precision**: TP / (TP + FP)
#
# **F1**: (2 * R * P) / (R + P)

# %%
# !python3 segment/val.py --data data/val.yaml --img 1024 --batch 4 --conf 0.001 --iou 0.5 --device 0 --weights 'runs/train-seg/exercise2_yolov9_seg_train/weights/best.pt' --save-json --name exercise2_yolov9_seg_val
# Out:
# segment/val: data=data/val.yaml, weights=['runs/train-seg/exercise2_yolov9_seg_train/weights/best.pt'], batch_size=4, imgsz=1024, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val-seg, name=exercise2_yolov9_seg_val, exist_ok=False, half=False, dnn=False
# YOLO 🚀 2024-6-25 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c-seg_custom summary: 414 layers, 27362899 parameters, 0 gradients
# val: Scanning /content/MLArchaeologyBasics/yolov9/dataset/val.cache... 6 images, 0 backgrounds, 0 corrupt: 100% 6/6 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:28<00:00, 14.24s/it]
#                    all          6         63      0.895       0.73      0.868      0.518      0.938      0.724      0.863      0.454
# Speed: 2.2ms pre-process, 161.0ms inference, 119.8ms NMS per image at shape (4, 3, 1024, 1024)
#
# Evaluating pycocotools mAP... saving runs/val-seg/exercise2_yolov9_seg_val/best_predictions.json...
# loading annotations into memory...
# pycocotools unable to run: [Errno 2] No such file or directory: '/content/MLArchaeologyBasics/yolov9/annotations/instances_val2017.json'
# Results saved to runs/val-seg/exercise2_yolov9_seg_val

# %%
import os
from IPython.display import display, Image
directory = '/content/MLArchaeologyBasics/yolov9/runs/val-seg/exercise2_yolov9_seg_val/'
for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".jpeg"):
        display(Image(filename=os.path.join(directory, filename)))

# %% [markdown]
# ### 4. Algorithm Evaluation: Testing Dataset
#
# **Recall**: TP / (TP + FN)
#
# **Precision**: TP / (TP + FP)
#
# **F1**: (2 * R * P) / (R + P)

# %%
# !python3 segment/val.py --data data/test.yaml --img 1024 --batch 4 --conf 0.001 --iou 0.5 --device 0 --weights 'runs/train-seg/exercise2_yolov9_seg_train/weights/best.pt' --save-json --name exercise2_yolov9_seg_test
# Out:
# segment/val: data=data/test.yaml, weights=['runs/train-seg/exercise2_yolov9_seg_train/weights/best.pt'], batch_size=4, imgsz=1024, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val-seg, name=exercise2_yolov9_seg_test, exist_ok=False, half=False, dnn=False
# YOLO 🚀 2024-6-25 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c-seg_custom summary: 414 layers, 27362899 parameters, 0 gradients
# val: Scanning /content/MLArchaeologyBasics/yolov9/dataset/test... 6 images, 0 backgrounds, 0 corrupt: 100% 6/6 [00:00<00:00, 212.59it/s]
# val: New cache created: /content/MLArchaeologyBasics/yolov9/dataset/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:27<00:00, 13.66s/it]
#                    all          6         65      0.782      0.828      0.882      0.542      0.768      0.813      0.844      0.504
# Speed: 17.8ms pre-process, 142.7ms inference, 102.2ms NMS per image at shape (4, 3, 1024, 1024)
#
# Evaluating pycocotools mAP... saving runs/val-seg/exercise2_yolov9_seg_test/best_predictions.json...
# loading annotations into memory...
# pycocotools unable to run: [Errno 2] No such file or directory: '/content/MLArchaeologyBasics/yolov9/annotations/instances_val2017.json'
# Results saved to runs/val-seg/exercise2_yolov9_seg_test

# %%
import os
from IPython.display import display, Image
directory = '/content/MLArchaeologyBasics/yolov9/runs/val-seg/exercise2_yolov9_seg_test/'
for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".jpeg"):
        display(Image(filename=os.path.join(directory, filename)))

# %% [markdown]
# ### 5. How to Improve the Algorithm
#
# **Hyperparameters**: Increase Epoch Number
#
# **Little Amount of Training Data**: Data Augmentation
#
# **False Positives**: Negative Training & Filters
#
# **ArchaeolDA**: https://github.com/iberganzo/ArchaeolDA
#
# **VIAtoYOLO**: https://github.com/iberganzo/VIAtoYOLO
#
# **Published Article**: https://doi.org/10.1002/arp.1822
